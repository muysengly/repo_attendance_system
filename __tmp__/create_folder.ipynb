# %%
import os
import re
import numpy as np

# %%
data = np.loadtxt("./name.csv", dtype=str, delimiter=",")
data
# Out:
# array(['AN VANNEATH', 'CHEAL RACHHANN'], dtype='<U14')

# %%
# create folders for each name
for name in data:
    os.makedirs(name, exist_ok=True)
